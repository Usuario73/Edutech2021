# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import folium

# %%
data = pd.read_excel("/content/data.xlsx")
data.head()

data.columns
# Out:
# Index(['ano censo', 'numero de vagas', 'numero de tipo de ingressos',
#        'numero de matriculas', 'numero de concluintes', 'numero de inscritos',
#        'numero de cursos', 'nome/regiao'],
#       dtype='object')

# %%
data.tail()
# Out:
#     ano censo  numero de vagas  ...  numero de cursos   nome/regiao
# 48       2009           335822  ...              2504  centro-oeste
# 49       2009           515028  ...              4655      nordeste
# 50       2009           193168  ...              2004         norte
# 51       2009          1998509  ...             13278       sudeste
# 52       2009           471865  ...              5386           sul
#
# [5 rows x 8 columns]

# %%
data.describe()
# Out:
#          ano censo  numero de vagas  ...  numero de inscritos  numero de cursos
# count    53.000000     5.300000e+01  ...         5.300000e+01         53.000000
# mean   2012.981132     1.544381e+06  ...         3.640432e+06       9405.679245
# std       2.627448     1.625355e+06  ...         4.241316e+06      10739.945630
# min    2009.000000     1.575450e+05  ...         2.066000e+03          0.000000
# 25%    2011.000000     4.463570e+05  ...         8.603490e+05       2427.000000
# 50%    2013.000000     7.326490e+05  ...         1.541681e+06       5709.000000
# 75%    2015.000000     2.109240e+06  ...         5.514733e+06      14416.000000
# max    2017.000000     6.180251e+06  ...         1.502419e+07      33522.000000
#
# [8 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# ano censo                      0
# numero de vagas                0
# numero de tipo de ingressos    0
# numero de matriculas           0
# numero de concluintes          0
# numero de inscritos            0
# numero de cursos               0
# nome/regiao                    0
# dtype: int64

# %% [markdown]
# *Transformando os dados em Gráficos:*

# %% [markdown]
# Após relacionar os valores das colunas `ano censo, numero de vagas e nome/regiao`
# o resultado foi:

# %%
sns.relplot(x="ano censo", y="numero de vagas",hue="nome/regiao", kind="line", data=data);

# %% [markdown]
# As próximas colunas a serem plotadas são:` numero de tipo,de ingressos, numero de matriculas, numero de concluintes, numero de inscritos,numero de cursos	`

# %%
sns.relplot(x="ano censo", y="numero de tipo de ingressos",hue="nome/regiao", kind="line", data=data);

# %%
sns.relplot(x="ano censo", y="numero de vagas",hue="nome/regiao", kind="line", data=data);

# %%
sns.relplot(x="ano censo", y="numero de concluintes",hue="nome/regiao", kind="line", data=data);

# %%
sns.relplot(x="ano censo", y="numero de inscritos",hue="nome/regiao", kind="line", data=data);

# %%
sns.relplot(x="ano censo", y="numero de cursos",hue="nome/regiao", kind="line", data=data);

# %% [markdown]
# # O percentual de aprovação nas respectivas regiões foi:

# %%
m = folium.Map(location=[-7.964819261115585, -55.49217566628385], max_zoom=4, tiles='Stamen Terrain')
folium.Marker(location=[-6.744497712581594, -55.93162877034453],
              popup=' Brasil aumentou 72.2% no numero de vagas entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(location=[-9.181515201946265, -55.93162877034453],
              popup=' Brasil aumentou 23.2% no numero de tipos de ingresso entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(location=[-8.312840239081671, -58.21678491146008],
              popup=' Brasil aumentou 27.6% no numero de matriculas entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(location=[-7.877767271138998, -55.93162877034453],
              popup=' Brasil aumentou 14.5% no numero de concluintes entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(location=[-8.486735788331847, -53.03123828354402],
              popup=' Brasil aumentou 103% no numero de inscritos entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)
folium.Marker(location=[-9.528401443807608, -55.58006628709599],
              popup=' Brasil aumentou 20% no numero de cursos entre 2009 e 2017',
              icon=folium.Icon(color='red', icon='info-sign')
).add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.co
# ...

# %% [markdown]
# # Conclusão Final
# O aumento no numero de inscritos nas mais diversas faculdades deve-se, ao fato do mercado de trabalho necessitar cada vez mais de profissionais capacitados.
# Como observado em https://blog.eseg.edu.br/empregabilidade-no-brasil/
